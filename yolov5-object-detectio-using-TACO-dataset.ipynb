# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17483, done.
# remote: Total 17483 (delta 0), reused 0 (delta 0), pack-reused 17483 (from 1)
# Receiving objects: 100% (17483/17483), 16.55 MiB | 17.84 MiB/s, done.
# Resolving deltas: 100% (11995/11995), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...

# %%
# !curl -L "https://universe.roboflow.com/ds/IJ4xUF3UKg?key=zKDHhjumI7" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/labels/000055_JPG_jpg.rf.9fe266cb29fc471e50a3113363781d45.txt
#  extracting: train/labels/000055_JPG_jpg.rf.a0ffded1b4df9285e860a02c3451e0b3.txt
#  extracting: train/labels/000055_JPG_jpg.rf.afd2c85571e873f9f67b964f56ff44c2.txt
#  extracting: train/labels/000055_JPG_jpg.rf.f8c66618a413ef0343b5170d12a09784.txt
#  extracting: train/labels/000055_JPG_jpg.rf.fbc18cc7703a8884f77cb2797ff8fda5.txt
#  extracting: train/labels/000055_JPG_jpg.rf.ff45590651469ae1234a48aecbb88111.txt
#  extracting: train/labels/000055_jpg.rf.0351831ddeffd9976bd5c2cf6412653f.txt
#  extracting: train/labels/000055_jpg.rf.0474fd3546be716dad7c02c2e16a9387.txt
#  extracting: train/labels/000055_jpg.rf.09bdd21b33e157972eadd3d130ced002.txt
#  extracting: train/labels/000055_jpg.rf.0b4a464aedc4f463d914270a040e2e0e.txt
#  extracting: train/labels/000055_jpg.rf.107817cad59a8170fffe9b1139189592.txt
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 10 --data ./data.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#         0/9      1.61G     0.1124    0.02182    0.07377         73        416:  64% 169/263 [00:28<00:11,  8.11it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9      1.61G     0.1122    0.02183    0.07376         57        416:  65% 170/263 [00:28<00:12,  7.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9      1.61G     0.1121    0.02181    0.07373         51        416:  65% 171/263 [00:28<00:12,  7.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.25 --source path_to_your_image.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=path_to_your_image.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-419-gcd44191c Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 438, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 433, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-acd35607-d588-4f8b-a505-170e60c0042b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acd35607-d588-4f8b-a505-170e60c0042b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.25 --source test_image.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=test_image.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-419-gcd44191c Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# image 1/1 /content/yolov5/test_image.jpg: 416x416 1 Carton, 7.1ms
# Speed: 0.4ms pre-process, 7.1ms inference, 145.4ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp3
